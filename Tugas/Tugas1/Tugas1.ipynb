# %%
import pandas as pd
import numpy as np

# %%
biodata = pd.read_csv('biodata.csv')
kemampuan = pd.read_csv('kemampuan.csv')
biodata
# Out:
#            ID                  Name  Age          Nationality  \
# 0      158023              L. Messi   31            Argentina
# 1       20801     Cristiano Ronaldo   33             Portugal
# 2      190871             Neymar Jr   26               Brazil
# 3      193080                De Gea   27                Spain
# 4      192985          K. De Bruyne   27              Belgium
# 5      183277             E. Hazard   27              Belgium
# 6      177003             L. Modrić   32              Croatia
# 7      176580             L. Suárez   31              Uruguay
# 8      155862          Sergio Ramos   32                Spain
# 9      200389              J. Oblak   25             Slovenia
# 10     188545        R. Lewandowski   29               Poland
# 11     182521              T. Kroos   28              Germany
# 12     182493              D. Godín   32              Uruguay
# 13     168542           David Silva   32                Spain
# ...

# %%
kemampuan
# Out:
#            ID  Crossing  Finishing  HeadingAccuracy  ShortPassing  Volleys  \
# 0      158023      84.0       95.0             70.0          90.0     86.0
# 1       20801      84.0       94.0             89.0          81.0     87.0
# 2      190871      79.0       87.0             62.0          84.0     84.0
# 3      193080      17.0       13.0             21.0          50.0     13.0
# 4      192985      93.0       82.0             55.0          92.0     82.0
# 5      183277      81.0       84.0             61.0          89.0     80.0
# 6      177003      86.0       72.0             55.0          93.0     76.0
# 7      176580      77.0       93.0             77.0          82.0     88.0
# 8      155862      66.0       60.0             91.0          78.0     66.0
# 9      200389      13.0       11.0             15.0          29.0     13.0
# 10     188545      62.0       91.0             85.0          83.0     89.0
# ...

# %%
#menggabungkan dua tabel
data = pd.merge(biodata, kemampuan, on ='ID')
data
# Out:
#            ID                  Name  Age          Nationality  \
# 0      158023              L. Messi   31            Argentina
# 1       20801     Cristiano Ronaldo   33             Portugal
# 2      190871             Neymar Jr   26               Brazil
# 3      193080                De Gea   27                Spain
# 4      192985          K. De Bruyne   27              Belgium
# 5      183277             E. Hazard   27              Belgium
# 6      177003             L. Modrić   32              Croatia
# 7      176580             L. Suárez   31              Uruguay
# 8      155862          Sergio Ramos   32                Spain
# 9      200389              J. Oblak   25             Slovenia
# 10     188545        R. Lewandowski   29               Poland
# 11     182521              T. Kroos   28              Germany
# 12     182493              D. Godín   32              Uruguay
# 13     168542           David Silva   32                Spain
# ...

# %%
data['AverageGK'] = (data['GKDiving']+data['GKHandling']+data['GKKicking']+data['GKPositioning']+data['GKReflexes'])/5
data
# Out:
#            ID                  Name  Age          Nationality  \
# 0      158023              L. Messi   31            Argentina
# 1       20801     Cristiano Ronaldo   33             Portugal
# 2      190871             Neymar Jr   26               Brazil
# 3      193080                De Gea   27                Spain
# 4      192985          K. De Bruyne   27              Belgium
# 5      183277             E. Hazard   27              Belgium
# 6      177003             L. Modrić   32              Croatia
# 7      176580             L. Suárez   31              Uruguay
# 8      155862          Sergio Ramos   32                Spain
# 9      200389              J. Oblak   25             Slovenia
# 10     188545        R. Lewandowski   29               Poland
# 11     182521              T. Kroos   28              Germany
# 12     182493              D. Godín   32              Uruguay
# 13     168542           David Silva   32                Spain
# ...

# %%
data.Nationality == 'Belgium'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19        True
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18177    False
# 18178    False
# 18179    False
# 18180    False
# 18181    False
# 18182    False
# 18183    False
# 18184    False
# 18185    False
# 18186    False
# 18187    False
# 18188    False
# 18189    False
# 18190    False
# 18191    False
# 18192    False
# 18193    False
# 18194    False
# 18195    False
# 18196    False
# 18197    False
# 18198    False
# 18199    False
# 18200    False
# 18201    False
# 18202    False
# 18203    False
# ...

# %%
data[data['Nationality'] == 'Belgium']
# Out:
#            ID             Name  Age Nationality                      Club  \
# 4      192985     K. De Bruyne   27     Belgium           Manchester City
# 5      183277        E. Hazard   27     Belgium                   Chelsea
# 19     192119      T. Courtois   26     Belgium               Real Madrid
# 47     192505        R. Lukaku   25     Belgium         Manchester United
# 50     175943       D. Mertens   31     Belgium                    Napoli
# 51     172871    J. Vertonghen   31     Belgium         Tottenham Hotspur
# 71     184087  T. Alderweireld   29     Belgium         Tottenham Hotspur
# 101    178518    R. Nainggolan   30     Belgium                     Inter
# 107    139720       V. Kompany   32     Belgium           Manchester City
# 143    177413        A. Witsel   29     Belgium         Borussia Dortmund
# 173    208418      Y. Carrasco   24     Belgium          Dalian YiFang FC
# 220    162240       M. Dembélé   30     Belgium         Tottenham Hotspur
# ...

# %%
# menghapus kolom
data1 = data.drop(['Work Rate','Position'], axis=1)
data1
# Out:
#            ID                  Name  Age          Nationality  \
# 0      158023              L. Messi   31            Argentina
# 1       20801     Cristiano Ronaldo   33             Portugal
# 2      190871             Neymar Jr   26               Brazil
# 3      193080                De Gea   27                Spain
# 4      192985          K. De Bruyne   27              Belgium
# 5      183277             E. Hazard   27              Belgium
# 6      177003             L. Modrić   32              Croatia
# 7      176580             L. Suárez   31              Uruguay
# 8      155862          Sergio Ramos   32                Spain
# 9      200389              J. Oblak   25             Slovenia
# 10     188545        R. Lewandowski   29               Poland
# 11     182521              T. Kroos   28              Germany
# 12     182493              D. Godín   32              Uruguay
# 13     168542           David Silva   32                Spain
# ...

# %%
# menghapus baris
data2 = data.drop([1111])
data2
# Out:
#            ID                  Name  Age          Nationality  \
# 0      158023              L. Messi   31            Argentina
# 1       20801     Cristiano Ronaldo   33             Portugal
# 2      190871             Neymar Jr   26               Brazil
# 3      193080                De Gea   27                Spain
# 4      192985          K. De Bruyne   27              Belgium
# 5      183277             E. Hazard   27              Belgium
# 6      177003             L. Modrić   32              Croatia
# 7      176580             L. Suárez   31              Uruguay
# 8      155862          Sergio Ramos   32                Spain
# 9      200389              J. Oblak   25             Slovenia
# 10     188545        R. Lewandowski   29               Poland
# 11     182521              T. Kroos   28              Germany
# 12     182493              D. Godín   32              Uruguay
# 13     168542           David Silva   32                Spain
# ...
